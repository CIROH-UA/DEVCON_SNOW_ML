# %%
import pickle
file_path = "/home/jovyan/DEVCON_SNOW_ML/data/Optimal_Features.pkl"
file_path_original = "/home/jovyan/DEVCON_SNOW_ML/data/RegionTrain_SCA.pkl"

# %%
with open(file_path, 'rb') as file:
    features = pickle.load(file)
file.close()

# %%
with open(file_path_original, 'rb') as file:
    train_data = pickle.load(file)
file.close()

# %%
train_data.keys()
# Out:
# dict_keys(['N_Sierras', 'S_Sierras_Low', 'S_Sierras_High'])

# %%
train_data
# Out:
# {'N_Sierras':                                            Date        Long        Lat  \
#  index
#  00c4db22-a423-41a4-ada6-a8b1b04153a4 2013-01-08 -121.939413  41.166647
#  00c4db22-a423-41a4-ada6-a8b1b04153a4 2013-01-15 -121.939413  41.166647
#  00c4db22-a423-41a4-ada6-a8b1b04153a4 2013-01-22 -121.939413  41.166647
#  00c4db22-a423-41a4-ada6-a8b1b04153a4 2013-01-29 -121.939413  41.166647
#  00c4db22-a423-41a4-ada6-a8b1b04153a4 2013-02-05 -121.939413  41.166647
#  ...                                         ...         ...        ...
#  df01bf44-46b8-4541-b0a4-ed1fae16ac38 2019-06-25 -121.319576  39.814023
#  df01bf44-46b8-4541-b0a4-ed1fae16ac38 2019-12-10 -121.319576  39.814023
#  df01bf44-46b8-4541-b0a4-ed1fae16ac38 2019-12-17 -121.319576  39.814023
#  df01bf44-46b8-4541-b0a4-ed1fae16ac38 2019-12-24 -121.319576  39.814023
#  df01bf44-46b8-4541-b0a4-ed1fae16ac38 2019-12-31 -121.319576  39.814023
#
#                                        elevation_m   SWE  WYWeek  northness  \
# ...
